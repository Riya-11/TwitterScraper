# %%
from bs4 import BeautifulSoup
import re
import nltk
from nltk.corpus import stopwords
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client["tweets_spacex2"] #Data gets stored in "tweets_spacex" db
collection = db.tweets_spacex2
tweets = pd.DataFrame(list(collection.find()))

# %%
replace_with_space = re.compile('[/(){}\[\]\|@,;]')
deleteSymbol = re.compile('[^0-9a-z #+_]')
stopwords = set(stopwords.words('english'))

def cleanText(text):
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = replace_with_space.sub(' ', text) # replace certain symbols by space in text
    text = deleteSymbol.sub('', text) # delete symbols from text
    text = ' '.join(word for word in text.split() if word not in stopwords) # remove stopwords from text
    return text

# %%
tweets.head()
# Out:
#                         _id                      created_at  \
# 0  5ee4cd2a1725c73dae0a6021  Sat Jun 13 12:57:12 +0000 2020
# 1  5ee4cd2a1725c73dae0a6022  Sat Jun 13 12:57:12 +0000 2020
# 2  5ee4cd2a1725c73dae0a6023  Sat Jun 13 12:57:12 +0000 2020
# 3  5ee4cd2a1725c73dae0a6024  Sat Jun 13 12:57:08 +0000 2020
# 4  5ee4cd2a1725c73dae0a6025  Sat Jun 13 12:57:07 +0000 2020
#
#                     id               id_str  \
# 0  1271788713966632961  1271788713966632961
# 1  1271788713178214406  1271788713178214406
# 2  1271788710913327104  1271788710913327104
# 3  1271788695146856448  1271788695146856448
# 4  1271788692550512640  1271788692550512640
#
#                                                 text  truncated  \
# 0  RT @jeff_foust: Worth noting: SpaceX has perfo...      False
# 1  @TimoV @SpaceX @planetlabs Yeah true not reall...      False
# 2  RT @stephenwpatrick: Beautiful morning for a l...      False
# 3  RT @SpaceX: Falcon 9’s first stage has landed ...      False
# 4  RT @SpaceX: Falcon 9 launches 58 Starlink sate...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [{'text': 'SpaceX', 'indices': [8...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="http://twitter.com/download/android" ...           1.271788e+18
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    ... quoted_status_id  quoted_status_id_str retweet_count favorite_count  \
# 0  ...     1.271752e+18   1271751994189983746             3              0
# 1  ...              NaN                   NaN             0              0
# 2  ...              NaN                   NaN             3              0
# 3  ...              NaN                   NaN          3602              0
# 4  ...              NaN                   NaN          2895              0
#
#   favorited retweeted lang                                  extended_entities  \
# 0     False     False   en                                                NaN
# 1     False     False   en                                                NaN
# 2     False     False   en  {'media': [{'id': 1271740182736384000, 'id_str...
# 3     False     False   en  {'media': [{'id': 1271736693654196224, 'id_str...
# 4     False     False   en                                                NaN
#
#   possibly_sensitive quoted_status
# 0                NaN           NaN
# 1                NaN           NaN
# 2              False           NaN
# 3              False           NaN
# 4                NaN           NaN
#
# [5 rows x 31 columns]

# %%
tweets['text'] = tweets['text'].apply(cleanText)

# %%
tweets.to_csv('spaceXTweets.csv',index=False)
